# %%
# adding the project directory to system path
import os
import sys

sys.path.append(os.path.abspath(".."))
os.makedirs("results", exist_ok=True)

# %%
# importing required librabries
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
# this is for better plot design
import matplotx as mpx
# for reducing high dimensional features
from sklearn.decomposition import PCA
# import data_loader for loading dataset
from src.data_loader import Load_Data
# data Scaling
from sklearn.preprocessing import StandardScaler
# for feature selection(experiment)
from sklearn.feature_selection import f_classif,SelectKBest
# remvoing zero varience
from sklearn.feature_selection import VarianceThreshold

# %%
# loading the TCGA Dataset
df = Load_Data()
df
# Out:
#        SampleID  gene_0    gene_1    gene_2    gene_3     gene_4  gene_5  \
# 0      sample_0     0.0  2.017209  3.265527  5.478487  10.431999     0.0
# 1      sample_1     0.0  0.592732  1.588421  7.586157   9.623011     0.0
# 2      sample_2     0.0  3.511759  4.327199  6.881787   9.870730     0.0
# 3      sample_3     0.0  3.663618  4.507649  6.659068  10.196184     0.0
# 4      sample_4     0.0  2.655741  2.821547  6.539454   9.738265     0.0
# ..          ...     ...       ...       ...       ...        ...     ...
# 796  sample_796     0.0  1.865642  2.718197  7.350099  10.006003     0.0
# 797  sample_797     0.0  3.942955  4.453807  6.346597  10.056868     0.0
# 798  sample_798     0.0  3.249582  3.707492  8.185901   9.504082     0.0
# 799  sample_799     0.0  2.590339  2.787976  7.318624   9.987136     0.0
# 800  sample_800     0.0  2.325242  3.805932  6.530246   9.560367     0.0
#
#        gene_6    gene_7  gene_8  ...  gene_20522  gene_20523  gene_20524  \
# ...

# %%
# Performing exploratory data analysis
df.shape
# Out:
# (801, 20533)

# %%
df.describe()
# Out:
#            gene_0      gene_1      gene_2      gene_3      gene_4  gene_5  \
# count  801.000000  801.000000  801.000000  801.000000  801.000000   801.0
# mean     0.026642    3.010909    3.095350    6.722305    9.813612     0.0
# std      0.136850    1.200828    1.065601    0.638819    0.506537     0.0
# min      0.000000    0.000000    0.000000    5.009284    8.435999     0.0
# 25%      0.000000    2.299039    2.390365    6.303346    9.464466     0.0
# 50%      0.000000    3.143687    3.127006    6.655893    9.791599     0.0
# 75%      0.000000    3.883484    3.802534    7.038447   10.142324     0.0
# max      1.482332    6.237034    6.063484   10.129528   11.355621     0.0
#
#            gene_6      gene_7      gene_8      gene_9  ...  gene_20521  \
# count  801.000000  801.000000  801.000000  801.000000  ...  801.000000
# mean     7.405509    0.499882    0.016744    0.013428  ...    5.896573
# std      1.108237    0.508799    0.133635    0.204722  ...    0.746399
# ...

# %%
with plt.style.context(mpx.styles.dracula):
    plt.figure(figsize=(7,5),dpi=300)
    sns.countplot(x=df['Class'],color='violet')
    plt.xlabel('Cancer Types')
    plt.ylabel('Count')
    plt.title('Class Distribution')
    plt.savefig("../results/Class_Distribution.png", dpi=300, bbox_inches='tight')
    plt.show()

# there is some imbalance in Class Distribution

# %%
#checking null value
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
#checking duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
X = df.drop(['SampleID','Class'],axis = 1)
Y = df['Class']
X
# Out:
#      gene_0    gene_1    gene_2    gene_3     gene_4  gene_5    gene_6  \
# 0       0.0  2.017209  3.265527  5.478487  10.431999     0.0  7.175175
# 1       0.0  0.592732  1.588421  7.586157   9.623011     0.0  6.816049
# 2       0.0  3.511759  4.327199  6.881787   9.870730     0.0  6.972130
# 3       0.0  3.663618  4.507649  6.659068  10.196184     0.0  7.843375
# 4       0.0  2.655741  2.821547  6.539454   9.738265     0.0  6.566967
# ..      ...       ...       ...       ...        ...     ...       ...
# 796     0.0  1.865642  2.718197  7.350099  10.006003     0.0  6.764792
# 797     0.0  3.942955  4.453807  6.346597  10.056868     0.0  7.320331
# 798     0.0  3.249582  3.707492  8.185901   9.504082     0.0  7.536589
# 799     0.0  2.590339  2.787976  7.318624   9.987136     0.0  9.213464
# 800     0.0  2.325242  3.805932  6.530246   9.560367     0.0  7.957027
#
#        gene_7  gene_8  gene_9  ...  gene_20521  gene_20522  gene_20523  \
# ...

# %%
# Reducing Dimensions using PCA
x_pca = PCA(n_components=2).fit_transform(X)

# %%
with plt.style.context(mpx.styles.dracula):
    plt.figure(figsize = (7,5),dpi = 300)
    sns.scatterplot(x=x_pca[:,0],y=x_pca[:,1],hue = df['Class'].astype('category').cat.codes)
    plt.legend()
    plt.title('Cluster Formation of Classes')
    plt.savefig("../results/Cluster_Formation_of_Classes.png", dpi=300, bbox_inches='tight')
    plt.show()

# from the below Result we could see that each class form a Cluster
# therefore,there is some underlying pattern in this genes which could identify the Cancer class

# %%
# removing 0 variences
X_new = VarianceThreshold(threshold = 0).fit_transform(X)
# Scaling the data
X_scaled = StandardScaler().fit_transform(X_new)
# experimenting with feature selection
selector = SelectKBest(score_func = f_classif,k = 100)
x_select = selector.fit_transform(X_scaled,Y)

# %%
# Perfoming PCA again
x_100_pca = PCA(n_components = 2).fit_transform(x_select)

# %%
with plt.style.context(mpx.styles.dracula):
    plt.figure(figsize = (7,4),dpi = 300)
    sns.scatterplot(x=x_100_pca[:,0],y=x_100_pca[:,1],hue = df['Class'].astype('category').cat.codes)
    plt.legend()
    plt.title("PCA with 100 Selected Features")
    plt.savefig("../results/Cluster_Formation_of_Classes(100 features).png", dpi=300, bbox_inches='tight')
    plt.show()
